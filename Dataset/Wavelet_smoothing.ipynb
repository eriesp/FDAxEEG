# %% [markdown]
# # Wavelet smoothing

# %%
import numpy as np
import mne
import glob
import os
import matplotlib as plt

# %%
directory = os.getcwd()

path_adhd = "\ICA_filtered\ADHD"
matfiles_adhd = glob.glob(directory + path_adhd + '/*.edf')

#path_control = "\Control"
#matfiles_control = glob.glob(directory + path_control + '/*.mat')

# %%
matfiles_adhd
# Out:
# ['c:\\Users\\erica\\Documents\\UNI\\NECSTCamp\\NL2\\Project-git\\FDAxEEG\\Dataset\\ICA_filtered\\ADHD\\v1p_edf.edf']

# %%
raw = mne.io.read_raw_edf(matfiles_adhd[0])
# Out:
# Extracting EDF parameters from c:\Users\erica\Documents\UNI\NECSTCamp\NL2\Project-git\FDAxEEG\Dataset\ICA_filtered\ADHD\v1p_edf.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
signals = raw.get_data()

# %%
signals[1:3]
# Out:
# array([[-1.15279003e-05,  9.53721303e-05,  1.98675255e-04, ...,
#         -5.60038000e-04, -5.60038000e-04, -5.60038000e-04],
#        [ 5.42491684e-05,  1.99198314e-06,  4.05493642e-05, ...,
#         -7.24738000e-04, -7.24738000e-04, -7.24738000e-04]])

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>
